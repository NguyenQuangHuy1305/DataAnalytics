# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("job-market.csv")
df = df.dropna(how="all")

# %%
classifications = df.Classification.unique()
locations = df.Location.unique()
# location_Sydney = df[df.Location.eq("Sydney")]
# location_Brisbane = df[df.Location=="Brisbane"]

# %%
df.head()
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 2                             LB Creative Pty Ltd  2018-10-07T00:00:00.000Z
# 3                          Anaconda Group Pty Ltd  2018-10-07T00:00:00.000Z
# 4  Commonwealth Bank - Business & Private Banking  2018-10-07T00:00:00.000Z
#
#                   Location                         Area  \
# 0                   Sydney  North West & Hills District
# 1    Richmond & Hawkesbury                          NaN
# 2                 Brisbane          CBD & Inner Suburbs
# 3  Gosford & Central Coast                          NaN
# 4                   Sydney        Ryde & Macquarie Park
#
#                    Classification  SubClassification  \
# 0      Retail & Consumer Products  Retail Assistants
# 1      Retail & Consumer Products  Retail Assistants
# 2      Retail & Consumer Products  Retail Assistants
# 3      Retail & Consumer Products  Retail Assistants
# 4  Call Centre & Customer Service    Sales - Inbound
#
#                                          Requirement FullDescription  \
# 0  Our Casual Stock Replenishers pride themselves...             NaN
# 1  Our Casual Stock Replenishers pride themselves...             NaN
# 2  BRAND NEW FLAGSHIP STORE OPENING - SUNSHINE PLAZA             NaN
# 3  Bring it on - do you love the great outdoors a...             NaN
# 4  We are seeking highly articulate, enthusiastic...             NaN
#
#    LowestSalary  HighestSalary JobType
# 0           0.0           30.0     NaN
# 1           0.0           30.0     NaN
# 2           0.0           30.0     NaN
# 3           0.0           30.0     NaN
# 4           0.0           30.0     NaN

# %%
# group the data by Location, assign corresponding Classification's count to each location

heatmap_data = df.groupby('Location').Classification.value_counts().unstack().fillna(0)

#draw the heatmap

plt.figure(figsize=(16, 20))
heatmap = sns.heatmap(heatmap_data, cmap='Blues', annot = True, fmt = ".0f")
heatmap.set_title('Number of jobs by locations', fontdict={'fontsize':12}, pad=12);

# %%
list(enumerate(locations))
number_of_rows = len(locations)//3 + 1
plt.figure(figsize = (50,250))

# each loop is a plot
for i in enumerate(locations):
    plt.subplot(number_of_rows, 3, i[0]+1)
    plt.tight_layout()
    location_name = df[df.Location.eq(i[1])]
    sns.countplot(y="Classification", data=location_name).set(title=i[1])

# %%
#salary ranges plot

# %%
# categorize salary range by creating a new column called SalaryRange with conditions
conditions = [
    (df['LowestSalary'] == 0) & (df['HighestSalary'] == 30),
    (df['LowestSalary'] == 30) & (df['HighestSalary'] == 40),
    (df['LowestSalary'] == 40) & (df['HighestSalary'] == 50),
    (df['LowestSalary'] == 50) & (df['HighestSalary'] == 60)
    ]

values = ["0-30", "30-40", "40-50", "50-60"]

df['SalaryRange'] = np.select(conditions, values)

# %%
slices = []

# get the count of each SalaryRange, then append to slices
for i in df.SalaryRange.value_counts():
    slices.append(i)

# labels used for the pie is the same as values
labels = values
# pretty colors
colors = sns.color_palette('pastel')[0:5]

plt.pie(slices, labels = labels, startangle=90, autopct = '%1.1f%%', colors = colors)
plt.title("Salary Range")
plt.tight_layout()

# %%
#OPTIONAL

locationDf = df[df['Location'].isna()==False] # remove n/a by selecting rows where row's Location is not n/a
locationDf = locationDf.groupby('Location').count() # group the locationDf by count of each Location, detail of groupby() look at lab1
locationDf['Location'] = locationDf.index # for some reason we lost Location column, so we must re-create it
locationDf['Count'] = locationDf["Id"] # id here is the count value from the dfgroupby object
locationDf.head()
# Out:
#                            Id  Title  Company  Date  Area  Classification  \
# Location
# ACT                       238    238      235   238     0             238
# Adelaide                  390    390      356   390     0             390
# Adelaide Hills & Barossa   19     19       18    19     0              19
# Albany & Great Southern    10     10       10    10     0              10
# Albury Area                19     19       18    19     0              19
#
#                           SubClassification  Requirement  FullDescription  \
# Location
# ACT                                     238          238              235
# Adelaide                                390          390              374
# Adelaide Hills & Barossa                 19           19               19
# Albany & Great Southern                  10           10               10
# Albury Area                              19           19               19
#
#                           LowestSalary  HighestSalary  JobType  SalaryRange  \
# Location
# ACT                                238            238      236          238
# Adelaide                           390            390      374          390
# Adelaide Hills & Barossa            19             19       19           19
# Albany & Great Southern             10             10       10           10
# Albury Area                         19             19       19           19
#
#                                           Location  Count
# Location
# ACT                                            ACT    238
# Adelaide                                  Adelaide    390
# Adelaide Hills & Barossa  Adelaide Hills & Barossa     19
# Albany & Great Southern    Albany & Great Southern     10
# Albury Area                            Albury Area     19

# %%
#OPTIONAL

# %matplotlib inline
# Pie char for job market share of cities
from matplotlib import cm

# %%
location_temp = []

for row in locationDf['Location']:
    if row == "Sydney": location_temp.append("Sydney")
    elif row == "Melbourne": location_temp.append("Melbourne")
    elif row == "Brisbane": location_temp.append("Brisbane")
    elif row == "Perth": location_temp.append("Perth")
    elif row == "Adelaide": location_temp.append("Adelaide")
    else: location_temp.append("Others")

locationDf['location_temp'] = location_temp
locationDf
# Out:
#                                       Id  Title  Company  Date  Area  \
# Location
# ACT                                  238    238      235   238     0
# Adelaide                             390    390      356   390     0
# Adelaide Hills & Barossa              19     19       18    19     0
# Albany & Great Southern               10     10       10    10     0
# Albury Area                           19     19       18    19     0
# ...                                  ...    ...      ...   ...   ...
# Western QLD                           19     19       19    19     0
# Whyalla & Eyre Peninsula              10     10       10    10     0
# Wollongong, Illawarra & South Coast   87     87       85    87     0
# Yarra Valley & High Country           36     36       34    36     0
# Yorke Peninsula & Clare Valley        11     11       10    11     0
#
#                                      Classification  SubClassification  \
# Location
# ACT                                             238                238
# Adelaide                                        390                390
# Adelaide Hills & Barossa                         19                 19
# Albany & Great Southern                          10                 10
# Albury Area                                      19                 19
# ...                                             ...                ...
# Western QLD                                      19                 19
# Whyalla & Eyre Peninsula                         10                 10
# Wollongong, Illawarra & South Coast              87                 87
# Yarra Valley & High Country                      36                 36
# Yorke Peninsula & Clare Valley                   11                 11
#
#                                      Requirement  FullDescription  \
# Location
# ACT                                          238              235
# Adelaide                                     390              374
# Adelaide Hills & Barossa                      19               19
# Albany & Great Southern                       10               10
# Albury Area                                   19               19
# ...                                          ...              ...
# Western QLD                                   19               19
# Whyalla & Eyre Peninsula                      10               10
# Wollongong, Illawarra & South Coast           87               87
# Yarra Valley & High Country                   36               35
# Yorke Peninsula & Clare Valley                11               11
#
#                                      LowestSalary  HighestSalary  JobType  \
# Location
# ACT                                           238            238      236
# Adelaide                                      390            390      374
# Adelaide Hills & Barossa                       19             19       19
# Albany & Great Southern                        10             10       10
# Albury Area                                    19             19       19
# ...                                           ...            ...      ...
# Western QLD                                    19             19       19
# Whyalla & Eyre Peninsula                       10             10       10
# Wollongong, Illawarra & South Coast            87             87       87
# Yarra Valley & High Country                    36             36       35
# Yorke Peninsula & Clare Valley                 11             11       11
#
#                                      SalaryRange  \
# Location
# ACT                                          238
# Adelaide                                     390
# Adelaide Hills & Barossa                      19
# Albany & Great Southern                       10
# Albury Area                                   19
# ...                                          ...
# Western QLD                                   19
# Whyalla & Eyre Peninsula                      10
# Wollongong, Illawarra & South Coast           87
# Yarra Valley & High Country                   36
# Yorke Peninsula & Clare Valley                11
#
#                                                                 Location  \
# Location
# ACT                                                                  ACT
# Adelaide                                                        Adelaide
# Adelaide Hills & Barossa                        Adelaide Hills & Barossa
# Albany & Great Southern                          Albany & Great Southern
# Albury Area                                                  Albury Area
# ...                                                                  ...
# Western QLD                                                  Western QLD
# Whyalla & Eyre Peninsula                        Whyalla & Eyre Peninsula
# Wollongong, Illawarra & South Coast  Wollongong, Illawarra & South Coast
# Yarra Valley & High Country                  Yarra Valley & High Country
# Yorke Peninsula & Clare Valley            Yorke Peninsula & Clare Valley
#
#                                      Count location_temp
# Location
# ACT                                    238        Others
# Adelaide                               390      Adelaide
# Adelaide Hills & Barossa                19        Others
# Albany & Great Southern                 10        Others
# Albury Area                             19        Others
# ...                                    ...           ...
# Western QLD                             19        Others
# Whyalla & Eyre Peninsula                10        Others
# Wollongong, Illawarra & South Coast     87        Others
# Yarra Valley & High Country             36        Others
# Yorke Peninsula & Clare Valley          11        Others
#
# [65 rows x 16 columns]

# %%
sum_Others = locationDf.loc[locationDf['location_temp'] == 'Others', 'Count'].sum()

slices = [sum_Others, 
          locationDf.loc['Adelaide', 'Count'], 
          locationDf.loc['Brisbane', 'Count'], 
          locationDf.loc['Melbourne', 'Count'], 
          locationDf.loc['Perth', 'Count'], 
          locationDf.loc['Sydney', 'Count']
         ]

labels = locationDf.location_temp.unique()

# pretty colors
colors = sns.color_palette('pastel')[0:6]

plt.pie(slices, labels = labels, startangle=90, autopct = '%1.1f%%', colors = colors)
plt.title("Job market share of cities")
plt.tight_layout()
